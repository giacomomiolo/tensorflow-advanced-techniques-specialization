# %% [markdown]
# ## Ungraded Lab: Lambda Layer
#
# This lab will show how you can define custom layers with the [Lambda](https://keras.io/api/layers/core_layers/lambda/) layer. You can either use [lambda functions](https://www.w3schools.com/python/python_lambda.asp) within the Lambda layer or define a custom function that the Lambda layer will call. Let's get started!

# %% [markdown]
# ## Imports

# %%
import tensorflow as tf
from tensorflow.keras import backend as K

# %% [markdown]
# ## Prepare the Dataset

# %%
mnist = tf.keras.datasets.mnist

(x_train, y_train),(x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

# %% [markdown]
# ## Build the Model
#
# Here, we'll use a Lambda layer to define a custom layer in our network. We're using a lambda function to get the absolute value of the layer input.

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(128),
  tf.keras.layers.Lambda(lambda x: tf.abs(x)), 
  tf.keras.layers.Dense(10, activation='softmax')
])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(x_train, y_train, epochs=5)
model.evaluate(x_test, y_test)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2226 - accuracy: 0.9364
# Epoch 2/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0906 - accuracy: 0.9731
# Epoch 3/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0648 - accuracy: 0.9800
# Epoch 4/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0483 - accuracy: 0.9849
# Epoch 5/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0397 - accuracy: 0.9877
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0885 - accuracy: 0.9741
# [0.0885232537984848, 0.9740999937057495]

# %% [markdown]
# Another way to use the Lambda layer is to pass in a function defined outside the model. The code below shows how a custom ReLU function is used as a custom layer in the model.

# %%
def my_relu(x):
    return K.maximum(-0.1, x)

model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128),
    tf.keras.layers.Lambda(my_relu), 
    tf.keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(x_train, y_train, epochs=5)
model.evaluate(x_test, y_test)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2558 - accuracy: 0.9264
# Epoch 2/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1138 - accuracy: 0.9661
# Epoch 3/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0777 - accuracy: 0.9764
# Epoch 4/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0580 - accuracy: 0.9818
# Epoch 5/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0429 - accuracy: 0.9868
# 313/313 [==============================] - 0s 990us/step - loss: 0.0757 - accuracy: 0.9778
# [0.07565587759017944, 0.9778000116348267]

# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Get the data from UCI dataset
URL = 'https://archive.ics.uci.edu/ml/machine-learning-databases/00242/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URL)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Epoch 1/500
# 62/62 [==============================] - 0s 5ms/step - loss: 248.9807 - y1_output_loss: 118.6596 - y2_output_loss: 130.3211 - y1_output_root_mean_squared_error: 10.8931 - y2_output_root_mean_squared_error: 11.4158 - val_loss: 45.4989 - val_y1_output_loss: 15.5540 - val_y2_output_loss: 29.9449 - val_y1_output_root_mean_squared_error: 3.9439 - val_y2_output_root_mean_squared_error: 5.4722
# Epoch 2/500
# 62/62 [==============================] - 0s 2ms/step - loss: 35.1956 - y1_output_loss: 13.4725 - y2_output_loss: 21.7231 - y1_output_root_mean_squared_error: 3.6705 - y2_output_root_mean_squared_error: 4.6608 - val_loss: 58.9928 - val_y1_output_loss: 11.7118 - val_y2_output_loss: 47.2810 - val_y1_output_root_mean_squared_error: 3.4223 - val_y2_output_root_mean_squared_error: 6.8761
# Epoch 3/500
# 62/62 [==============================] - 0s 2ms/step - loss: 29.6625 - y1_output_loss: 11.4471 - y2_output_loss: 18.2154 - y1_output_root_mean_squared_error: 3.3834 - y2_output_root_mean_squared_error: 4.2680 - val_loss: 20.7753 - val_y1_output_loss: 8.1107 - val_y2_output_loss: 12.6645 - val_y1_output_root_mean_squared_error: 2.8479 - val_y2_output_root_mean_squared_error: 3.5587
# Epoch 4/500
# 62/62 [==============================] - 0s 2ms/step - loss: 26.9290 - y1_output_loss: 9.7923 - y2_output_loss: 17.1367 - y1_output_root_mean_squared_error: 3.1293 - y2_output_root_mean_squared_error: 4.1397 - val_loss: 19.5291 - val_y1_output_loss: 8.5336 - val_y2_output_loss: 10.9955 - val_y1_output_root_mean_squared_error: 2.9212 - val_y2_output_root_mean_squared_error: 3.3160
# Epoch 5/500
# 62/62 [==============================] - 0s 1ms/step - loss: 28.0735 - y1_output_loss: 10.1577 - y2_output_loss: 17.9158 - y1_output_root_mean_squared_error: 3.1871 - y2_output_root_mean_squared_error: 4.2327 - val_loss: 35.5300 - val_y1_output_loss: 11.2608 - val_y2_output_loss: 24.2691 - val_y1_output_root_mean_squared_error: 3.3557 - val_y2_output_root_mean_squared_error: 4.9264
# Epoch 6/500
# 62/62 [==============================] - 0s 1ms/step - loss: 28.8574 - y1_output_loss: 10.1799 - y2_output_loss: 18.6776 - y1_output_root_mean_squared_error: 3.1906 - y2_output_root_mean_squared_error: 4.3218 - val_loss: 16.4962 - val_y1_output_loss: 7.1849 - val_y2_output_loss: 9.3114 - val_y1_output_root_mean_squared_error: 2.6805 - val_y2_output_root_mean_squared_error: 3.0515
# Epoch 7/500
# 62/62 [==============================] - 0s 1ms/step - loss: 26.0494 - y1_output_loss: 9.9180 - y2_output_loss: 16.1314 - y1_output_root_mean_squared_error: 3.1493 - y2_output_root_mean_squared_error: 4.0164 - val_loss: 18.4573 - val_y1_output_loss: 7.5969 - val_y2_output_loss: 10.8604 - val_y1_output_root_mean_squared_error: 2.7562 - val_y2_output_root_mean_squared_error: 3.2955
# Epoch 8/500
# 62/62 [==============================] - 0s 2ms/step - loss: 21.8318 - y1_output_loss: 8.7182 - y2_output_loss: 13.1136 - y1_output_root_mean_squared_error: 2.9527 - y2_output_root_mean_squared_error: 3.6213 - val_loss: 19.0899 - val_y1_output_loss: 6.1533 - val_y2_output_loss: 12.9366 - val_y1_output_root_mean_squared_error: 2.4806 - val_y2_output_root_mean_squared_error: 3.5967
# Epoch 9/500
# 62/62 [==============================] - 0s 1ms/step - loss: 22.3450 - y1_output_loss: 8.8722 - y2_output_loss: 13.4729 - y1_output_root_mean_squared_error: 2.9786 - y2_output_root_mean_squared_error: 3.6705 - val_loss: 39.4170 - val_y1_output_loss: 10.4310 - val_y2_output_loss: 28.9860 - val_y1_output_root_mean_squared_error: 3.2297 - val_y2_output_root_mean_squared_error: 5.3839
# Epoch 10/500
# 62/62 [==============================] - 0s 1ms/step - loss: 19.3838 - y1_output_loss: 8.0002 - y2_output_loss: 11.3836 - y1_output_root_mean_squared_error: 2.8285 - y2_output_root_mean_squared_error: 3.3740 - val_loss: 29.1720 - val_y1_output_loss: 7.8868 - val_y2_output_loss: 21.2852 - val_y1_output_root_mean_squared_error: 2.8083 - val_y2_output_root_mean_squared_error: 4.6136
# Epoch 11/500
# 62/62 [==============================] - 0s 1ms/step - loss: 26.5392 - y1_output_loss: 9.1630 - y2_output_loss: 17.3762 - y1_output_root_mean_squared_error: 3.0271 - y2_output_root_mean_squared_error: 4.1685 - val_loss: 11.7504 - val_y1_output_loss: 4.6925 - val_y2_output_loss: 7.0579 - val_y1_output_root_mean_squared_error: 2.1662 - val_y2_output_root_mean_squared_error: 2.6567
# Epoch 12/500
# 62/62 [==============================] - 0s 1ms/step - loss: 19.5292 - y1_output_loss: 7.9754 - y2_output_loss: 11.5538 - y1_output_root_mean_squared_error: 2.8241 - y2_output_root_mean_squared_error: 3.3991 - val_loss: 25.7904 - val_y1_output_loss: 9.1326 - val_y2_output_loss: 16.6578 - val_y1_output_root_mean_squared_error: 3.0220 - val_y2_output_root_mean_squared_error: 4.0814
# Epoch 13/500
# 62/62 [==============================] - 0s 1ms/step - loss: 20.7404 - y1_output_loss: 7.9037 - y2_output_loss: 12.8367 - y1_output_root_mean_squared_error: 2.8114 - y2_output_root_mean_squared_error: 3.5828 - val_loss: 30.8061 - val_y1_output_loss: 7.3776 - val_y2_output_loss: 23.4285 - val_y1_output_root_mean_squared_error: 2.7162 - val_y2_output_root_mean_squared_error: 4.8403
# Epoch 14/500
# 62/62 [==============================] - 0s 1ms/step - loss: 20.0304 - y1_output_loss: 7.3769 - y2_output_loss: 12.6535 - y1_output_root_mean_squared_error: 2.7160 - y2_output_root_mean_squared_error: 3.5572 - val_loss: 15.8996 - val_y1_output_loss: 6.8292 - val_y2_output_loss: 9.0704 - val_y1_output_root_mean_squared_error: 2.6133 - val_y2_output_root_mean_squared_error: 3.0117
# Epoch 15/500
# 62/62 [==============================] - 0s 1ms/step - loss: 18.5053 - y1_output_loss: 6.9861 - y2_output_loss: 11.5192 - y1_output_root_mean_squared_error: 2.6431 - y2_output_root_mean_squared_error: 3.3940 - val_loss: 38.7327 - val_y1_output_loss: 9.3247 - val_y2_output_loss: 29.4080 - val_y1_output_root_mean_squared_error: 3.0536 - val_y2_output_root_mean_squared_error: 5.4229
# Epoch 16/500
# 62/62 [==============================] - 0s 1ms/step - loss: 18.0921 - y1_output_loss: 7.0891 - y2_output_loss: 11.0030 - y1_output_root_mean_squared_error: 2.6625 - y2_output_root_mean_squared_error: 3.3171 - val_loss: 12.1623 - val_y1_output_loss: 5.2312 - val_y2_output_loss: 6.9312 - val_y1_output_root_mean_squared_error: 2.2872 - val_y2_output_root_mean_squared_error: 2.6327
# Epoch 17/500
# 62/62 [==============================] - 0s 1ms/step - loss: 23.3321 - y1_output_loss: 8.0885 - y2_output_loss: 15.2436 - y1_output_root_mean_squared_error: 2.8440 - y2_output_root_mean_squared_error: 3.9043 - val_loss: 9.7664 - val_y1_output_loss: 4.0694 - val_y2_output_loss: 5.6969 - val_y1_output_root_mean_squared_error: 2.0173 - val_y2_output_root_mean_squared_error: 2.3868
# Epoch 18/500
# 62/62 [==============================] - 0s 2ms/step - loss: 16.4447 - y1_output_loss: 6.3633 - y2_output_loss: 10.0813 - y1_output_root_mean_squared_error: 2.5226 - y2_output_root_mean_squared_error: 3.1751 - val_loss: 9.9711 - val_y1_output_loss: 3.5654 - val_y2_output_loss: 6.4057 - val_y1_output_root_mean_squared_error: 1.8882 - val_y2_output_root_mean_squared_error: 2.5309
# Epoch 19/500
# 62/62 [==============================] - 0s 2ms/step - loss: 14.9031 - y1_output_loss: 5.7331 - y2_output_loss: 9.1700 - y1_output_root_mean_squared_error: 2.3944 - y2_output_root_mean_squared_error: 3.0282 - val_loss: 10.8428 - val_y1_output_loss: 3.8318 - val_y2_output_loss: 7.0110 - val_y1_output_root_mean_squared_error: 1.9575 - val_y2_output_root_mean_squared_error: 2.6478
# Epoch 20/500
# 62/62 [==============================] - 0s 2ms/step - loss: 13.2952 - y1_output_loss: 5.4509 - y2_output_loss: 7.8443 - y1_output_root_mean_squared_error: 2.3347 - y2_output_root_mean_squared_error: 2.8008 - val_loss: 32.4965 - val_y1_output_loss: 7.3014 - val_y2_output_loss: 25.1950 - val_y1_output_root_mean_squared_error: 2.7021 - val_y2_output_root_mean_squared_error: 5.0195
# Epoch 21/500
# 62/62 [==============================] - 0s 1ms/step - loss: 16.2235 - y1_output_loss: 5.9160 - y2_output_loss: 10.3075 - y1_output_root_mean_squared_error: 2.4323 - y2_output_root_mean_squared_error: 3.2105 - val_loss: 12.0069 - val_y1_output_loss: 4.1784 - val_y2_output_loss: 7.8285 - val_y1_output_root_mean_squared_error: 2.0441 - val_y2_output_root_mean_squared_error: 2.7979
# Epoch 22/500
# 62/62 [==============================] - 0s 2ms/step - loss: 13.3804 - y1_output_loss: 5.0018 - y2_output_loss: 8.3786 - y1_output_root_mean_squared_error: 2.2365 - y2_output_root_mean_squared_error: 2.8946 - val_loss: 24.6000 - val_y1_output_loss: 5.6602 - val_y2_output_loss: 18.9398 - val_y1_output_root_mean_squared_error: 2.3791 - val_y2_output_root_mean_squared_error: 4.3520
# Epoch 23/500
# 62/62 [==============================] - 0s 2ms/step - loss: 11.0857 - y1_output_loss: 4.3894 - y2_output_loss: 6.6963 - y1_output_root_mean_squared_error: 2.0951 - y2_output_root_mean_squared_error: 2.5877 - val_loss: 30.0163 - val_y1_output_loss: 5.2942 - val_y2_output_loss: 24.7221 - val_y1_output_root_mean_squared_error: 2.3009 - val_y2_output_root_mean_squared_error: 4.9721
# Epoch 24/500
# 62/62 [==============================] - 0s 2ms/step - loss: 11.4712 - y1_output_loss: 4.4144 - y2_output_loss: 7.0568 - y1_output_root_mean_squared_error: 2.1010 - y2_output_root_mean_squared_error: 2.6565 - val_loss: 20.9616 - val_y1_output_loss: 6.9878 - val_y2_output_loss: 13.9738 - val_y1_output_root_mean_squared_error: 2.6434 - val_y2_output_root_mean_squared_error: 3.7382
# Epoch 25/500
# 62/62 [==============================] - 0s 1ms/step - loss: 11.1907 - y1_output_loss: 4.1195 - y2_output_loss: 7.0712 - y1_output_root_mean_squared_error: 2.0297 - y2_output_root_mean_squared_error: 2.6592 - val_loss: 9.6200 - val_y1_output_loss: 3.1885 - val_y2_output_loss: 6.4315 - val_y1_output_root_mean_squared_error: 1.7856 - val_y2_output_root_mean_squared_error: 2.5360
# Epoch 26/500
# 62/62 [==============================] - 0s 1ms/step - loss: 10.5852 - y1_output_loss: 3.9492 - y2_output_loss: 6.6360 - y1_output_root_mean_squared_error: 1.9873 - y2_output_root_mean_squared_error: 2.5760 - val_loss: 6.2541 - val_y1_output_loss: 2.0377 - val_y2_output_loss: 4.2164 - val_y1_output_root_mean_squared_error: 1.4275 - val_y2_output_root_mean_squared_error: 2.0534
# Epoch 27/500
# 62/62 [==============================] - 0s 1ms/step - loss: 9.9280 - y1_output_loss: 3.5724 - y2_output_loss: 6.3556 - y1_output_root_mean_squared_error: 1.8901 - y2_output_root_mean_squared_error: 2.5210 - val_loss: 7.2647 - val_y1_output_loss: 2.4624 - val_y2_output_loss: 4.8023 - val_y1_output_root_mean_squared_error: 1.5692 - val_y2_output_root_mean_squared_error: 2.1914
# Epoch 28/500
# 62/62 [==============================] - 0s 2ms/step - loss: 11.6811 - y1_output_loss: 3.8034 - y2_output_loss: 7.8777 - y1_output_root_mean_squared_error: 1.9502 - y2_output_root_mean_squared_error: 2.8067 - val_loss: 14.7340 - val_y1_output_loss: 3.6614 - val_y2_output_loss: 11.0726 - val_y1_output_root_mean_squared_error: 1.9135 - val_y2_output_root_mean_squared_error: 3.3276
# Epoch 29/500
# 62/62 [==============================] - 0s 1ms/step - loss: 16.9138 - y1_output_loss: 5.4486 - y2_output_loss: 11.4652 - y1_output_root_mean_squared_error: 2.3342 - y2_output_root_mean_squared_error: 3.3860 - val_loss: 12.1101 - val_y1_output_loss: 4.0972 - val_y2_output_loss: 8.0129 - val_y1_output_root_mean_squared_error: 2.0241 - val_y2_output_root_mean_squared_error: 2.8307
# Epoch 30/500
# 62/62 [==============================] - 0s 2ms/step - loss: 11.4467 - y1_output_loss: 4.0768 - y2_output_loss: 7.3698 - y1_output_root_mean_squared_error: 2.0191 - y2_output_root_mean_squared_error: 2.7147 - val_loss: 8.8106 - val_y1_output_loss: 3.5875 - val_y2_output_loss: 5.2231 - val_y1_output_root_mean_squared_error: 1.8941 - val_y2_output_root_mean_squared_error: 2.2854
# Epoch 31/500
# 62/62 [==============================] - 0s 2ms/step - loss: 10.2790 - y1_output_loss: 3.4990 - y2_output_loss: 6.7799 - y1_output_root_mean_squared_error: 1.8706 - y2_output_root_mean_squared_error: 2.6038 - val_loss: 10.1466 - val_y1_output_loss: 2.3314 - val_y2_output_loss: 7.8153 - val_y1_output_root_mean_squared_error: 1.5269 - val_y2_output_root_mean_squared_error: 2.7956
# Epoch 32/500
# 62/62 [==============================] - 0s 2ms/step - loss: 9.8287 - y1_output_loss: 3.3382 - y2_output_loss: 6.4905 - y1_output_root_mean_squared_error: 1.8271 - y2_output_root_mean_squared_error: 2.5476 - val_loss: 9.8640 - val_y1_output_loss: 3.8563 - val_y2_output_loss: 6.0078 - val_y1_output_root_mean_squared_error: 1.9637 - val_y2_output_root_mean_squared_error: 2.4511
# Epoch 33/500
# 62/62 [==============================] - 0s 1ms/step - loss: 9.1795 - y1_output_loss: 3.0678 - y2_output_loss: 6.1117 - y1_output_root_mean_squared_error: 1.7515 - y2_output_root_mean_squared_error: 2.4722 - val_loss: 12.4931 - val_y1_output_loss: 2.8012 - val_y2_output_loss: 9.6919 - val_y1_output_root_mean_squared_error: 1.6737 - val_y2_output_root_mean_squared_error: 3.1132
# Epoch 34/500
# 62/62 [==============================] - 0s 2ms/step - loss: 10.2647 - y1_output_loss: 3.2903 - y2_output_loss: 6.9745 - y1_output_root_mean_squared_error: 1.8139 - y2_output_root_mean_squared_error: 2.6409 - val_loss: 12.1335 - val_y1_output_loss: 4.4760 - val_y2_output_loss: 7.6574 - val_y1_output_root_mean_squared_error: 2.1157 - val_y2_output_root_mean_squared_error: 2.7672
# Epoch 35/500
# 62/62 [==============================] - 0s 3ms/step - loss: 10.4666 - y1_output_loss: 3.3023 - y2_output_loss: 7.1644 - y1_output_root_mean_squared_error: 1.8172 - y2_output_root_mean_squared_error: 2.6766 - val_loss: 9.9798 - val_y1_output_loss: 3.1088 - val_y2_output_loss: 6.8710 - val_y1_output_root_mean_squared_error: 1.7632 - val_y2_output_root_mean_squared_error: 2.6213
# Epoch 36/500
# 62/62 [==============================] - 0s 3ms/step - loss: 8.2820 - y1_output_loss: 2.9062 - y2_output_loss: 5.3758 - y1_output_root_mean_squared_error: 1.7048 - y2_output_root_mean_squared_error: 2.3186 - val_loss: 5.5078 - val_y1_output_loss: 1.8803 - val_y2_output_loss: 3.6275 - val_y1_output_root_mean_squared_error: 1.3712 - val_y2_output_root_mean_squared_error: 1.9046
# Epoch 37/500
# 62/62 [==============================] - 0s 1ms/step - loss: 9.2532 - y1_output_loss: 3.0569 - y2_output_loss: 6.1963 - y1_output_root_mean_squared_error: 1.7484 - y2_output_root_mean_squared_error: 2.4892 - val_loss: 5.2379 - val_y1_output_loss: 1.7145 - val_y2_output_loss: 3.5234 - val_y1_output_root_mean_squared_error: 1.3094 - val_y2_output_root_mean_squared_error: 1.8771
# Epoch 38/500
# 62/62 [==============================] - 0s 2ms/step - loss: 7.7702 - y1_output_loss: 2.5514 - y2_output_loss: 5.2188 - y1_output_root_mean_squared_error: 1.5973 - y2_output_root_mean_squared_error: 2.2845 - val_loss: 27.3788 - val_y1_output_loss: 8.5653 - val_y2_output_loss: 18.8135 - val_y1_output_root_mean_squared_error: 2.9267 - val_y2_output_root_mean_squared_error: 4.3375
# Epoch 39/500
# 62/62 [==============================] - 0s 2ms/step - loss: 10.3145 - y1_output_loss: 3.5271 - y2_output_loss: 6.7874 - y1_output_root_mean_squared_error: 1.8781 - y2_output_root_mean_squared_error: 2.6053 - val_loss: 6.4000 - val_y1_output_loss: 1.9096 - val_y2_output_loss: 4.4904 - val_y1_output_root_mean_squared_error: 1.3819 - val_y2_output_root_mean_squared_error: 2.1191
# Epoch 40/500
# 62/62 [==============================] - 0s 2ms/step - loss: 9.0542 - y1_output_loss: 3.0450 - y2_output_loss: 6.0092 - y1_output_root_mean_squared_error: 1.7450 - y2_output_root_mean_squared_error: 2.4514 - val_loss: 22.8683 - val_y1_output_loss: 5.0006 - val_y2_output_loss: 17.8677 - val_y1_output_root_mean_squared_error: 2.2362 - val_y2_output_root_mean_squared_error: 4.2270
# Epoch 41/500
# 62/62 [==============================] - 0s 2ms/step - loss: 7.8143 - y1_output_loss: 2.6191 - y2_output_loss: 5.1952 - y1_output_root_mean_squared_error: 1.6184 - y2_output_root_mean_squared_error: 2.2793 - val_loss: 6.8040 - val_y1_output_loss: 1.9180 - val_y2_output_loss: 4.8860 - val_y1_output_root_mean_squared_error: 1.3849 - val_y2_output_root_mean_squared_error: 2.2104
# Epoch 42/500
# 62/62 [==============================] - 0s 1ms/step - loss: 8.3210 - y1_output_loss: 2.6420 - y2_output_loss: 5.6789 - y1_output_root_mean_squared_error: 1.6254 - y2_output_root_mean_squared_error: 2.3831 - val_loss: 12.3595 - val_y1_output_loss: 3.6109 - val_y2_output_loss: 8.7487 - val_y1_output_root_mean_squared_error: 1.9002 - val_y2_output_root_mean_squared_error: 2.9578
# Epoch 43/500
# 62/62 [==============================] - 0s 2ms/step - loss: 8.6728 - y1_output_loss: 2.8923 - y2_output_loss: 5.7805 - y1_output_root_mean_squared_error: 1.7007 - y2_output_root_mean_squared_error: 2.4043 - val_loss: 16.7807 - val_y1_output_loss: 5.5544 - val_y2_output_loss: 11.2262 - val_y1_output_root_mean_squared_error: 2.3568 - val_y2_output_root_mean_squared_error: 3.3506
# Epoch 44/500
# 62/62 [==============================] - 0s 3ms/step - loss: 9.0094 - y1_output_loss: 2.8334 - y2_output_loss: 6.1760 - y1_output_root_mean_squared_error: 1.6833 - y2_output_root_mean_squared_error: 2.4852 - val_loss: 8.5226 - val_y1_output_loss: 1.7713 - val_y2_output_loss: 6.7513 - val_y1_output_root_mean_squared_error: 1.3309 - val_y2_output_root_mean_squared_error: 2.5983
# Epoch 45/500
# 62/62 [==============================] - 0s 2ms/step - loss: 8.3309 - y1_output_loss: 2.5387 - y2_output_loss: 5.7922 - y1_output_root_mean_squared_error: 1.5933 - y2_output_root_mean_squared_error: 2.4067 - val_loss: 7.2785 - val_y1_output_loss: 1.7085 - val_y2_output_loss: 5.5700 - val_y1_output_root_mean_squared_error: 1.3071 - val_y2_output_root_mean_squared_error: 2.3601
# Epoch 46/500
# 62/62 [==============================] - 0s 2ms/step - loss: 7.1897 - y1_output_loss: 2.2648 - y2_output_loss: 4.9249 - y1_output_root_mean_squared_error: 1.5049 - y2_output_root_mean_squared_error: 2.2192 - val_loss: 13.4162 - val_y1_output_loss: 2.9513 - val_y2_output_loss: 10.4650 - val_y1_output_root_mean_squared_error: 1.7179 - val_y2_output_root_mean_squared_error: 3.2350
# Epoch 47/500
# 62/62 [==============================] - 0s 2ms/step - loss: 8.2597 - y1_output_loss: 2.5004 - y2_output_loss: 5.7593 - y1_output_root_mean_squared_error: 1.5813 - y2_output_root_mean_squared_error: 2.3999 - val_loss: 5.9906 - val_y1_output_loss: 2.1207 - val_y2_output_loss: 3.8699 - val_y1_output_root_mean_squared_error: 1.4562 - val_y2_output_root_mean_squared_error: 1.9672
# Epoch 48/500
# 62/62 [==============================] - 0s 2ms/step - loss: 6.9072 - y1_output_loss: 2.1719 - y2_output_loss: 4.7353 - y1_output_root_mean_squared_error: 1.4738 - y2_output_root_mean_squared_error: 2.1761 - val_loss: 5.4251 - val_y1_output_loss: 1.8010 - val_y2_output_loss: 3.6241 - val_y1_output_root_mean_squared_error: 1.3420 - val_y2_output_root_mean_squared_error: 1.9037
# Epoch 49/500
# 62/62 [==============================] - 0s 1ms/step - loss: 11.6185 - y1_output_loss: 3.8332 - y2_output_loss: 7.7853 - y1_output_root_mean_squared_error: 1.9579 - y2_output_root_mean_squared_error: 2.7902 - val_loss: 13.3917 - val_y1_output_loss: 4.3099 - val_y2_output_loss: 9.0818 - val_y1_output_root_mean_squared_error: 2.0760 - val_y2_output_root_mean_squared_error: 3.0136
# Epoch 50/500
# 62/62 [==============================] - 0s 2ms/step - loss: 8.0415 - y1_output_loss: 2.3930 - y2_output_loss: 5.6484 - y1_output_root_mean_squared_error: 1.5469 - y2_output_root_mean_squared_error: 2.3766 - val_loss: 15.2341 - val_y1_output_loss: 4.8716 - val_y2_output_loss: 10.3625 - val_y1_output_root_mean_squared_error: 2.2072 - val_y2_output_root_mean_squared_error: 3.2191
# Epoch 51/500
# 62/62 [==============================] - 0s 2ms/step - loss: 7.1268 - y1_output_loss: 2.2028 - y2_output_loss: 4.9240 - y1_output_root_mean_squared_error: 1.4842 - y2_output_root_mean_squared_error: 2.2190 - val_loss: 7.3416 - val_y1_output_loss: 2.8792 - val_y2_output_loss: 4.4624 - val_y1_output_root_mean_squared_error: 1.6968 - val_y2_output_root_mean_squared_error: 2.1124
# Epoch 52/500
# 62/62 [==============================] - 0s 2ms/step - loss: 7.6359 - y1_output_loss: 2.4902 - y2_output_loss: 5.1457 - y1_output_root_mean_squared_error: 1.5780 - y2_output_root_mean_squared_error: 2.2684 - val_loss: 5.0409 - val_y1_output_loss: 1.3167 - val_y2_output_loss: 3.7243 - val_y1_output_root_mean_squared_error: 1.1475 - val_y2_output_root_mean_squared_error: 1.9298
# Epoch 53/500
# 62/62 [==============================] - 0s 2ms/step - loss: 7.2033 - y1_output_loss: 2.2280 - y2_output_loss: 4.9753 - y1_output_root_mean_squared_error: 1.4926 - y2_output_root_mean_squared_error: 2.2305 - val_loss: 7.4191 - val_y1_output_loss: 1.9227 - val_y2_output_loss: 5.4964 - val_y1_output_root_mean_squared_error: 1.3866 - val_y2_output_root_mean_squared_error: 2.3444
# Epoch 54/500
# 62/62 [==============================] - 0s 1ms/step - loss: 6.3119 - y1_output_loss: 1.9876 - y2_output_loss: 4.3244 - y1_output_root_mean_squared_error: 1.4098 - y2_output_root_mean_squared_error: 2.0795 - val_loss: 15.9413 - val_y1_output_loss: 5.0884 - val_y2_output_loss: 10.8529 - val_y1_output_root_mean_squared_error: 2.2557 - val_y2_output_root_mean_squared_error: 3.2944
# Epoch 55/500
# 62/62 [==============================] - 0s 2ms/step - loss: 5.9946 - y1_output_loss: 1.8036 - y2_output_loss: 4.1911 - y1_output_root_mean_squared_error: 1.3430 - y2_output_root_mean_squared_error: 2.0472 - val_loss: 8.7004 - val_y1_output_loss: 2.1569 - val_y2_output_loss: 6.5436 - val_y1_output_root_mean_squared_error: 1.4686 - val_y2_output_root_mean_squared_error: 2.5580
# Epoch 56/500
# 62/62 [==============================] - 0s 1ms/step - loss: 7.4952 - y1_output_loss: 2.2376 - y2_output_loss: 5.2576 - y1_output_root_mean_squared_error: 1.4959 - y2_output_root_mean_squared_error: 2.2929 - val_loss: 7.3940 - val_y1_output_loss: 2.4413 - val_y2_output_loss: 4.9527 - val_y1_output_root_mean_squared_error: 1.5625 - val_y2_output_root_mean_squared_error: 2.2255
# Epoch 57/500
# 62/62 [==============================] - 0s 1ms/step - loss: 7.2258 - y1_output_loss: 2.2703 - y2_output_loss: 4.9556 - y1_output_root_mean_squared_error: 1.5067 - y2_output_root_mean_squared_error: 2.2261 - val_loss: 4.8141 - val_y1_output_loss: 1.4922 - val_y2_output_loss: 3.3219 - val_y1_output_root_mean_squared_error: 1.2216 - val_y2_output_root_mean_squared_error: 1.8226
# Epoch 58/500
# 62/62 [==============================] - 0s 2ms/step - loss: 11.4193 - y1_output_loss: 3.7666 - y2_output_loss: 7.6527 - y1_output_root_mean_squared_error: 1.9408 - y2_output_root_mean_squared_error: 2.7663 - val_loss: 4.2910 - val_y1_output_loss: 1.2075 - val_y2_output_loss: 3.0835 - val_y1_output_root_mean_squared_error: 1.0989 - val_y2_output_root_mean_squared_error: 1.7560
# Epoch 59/500
# 62/62 [==============================] - 0s 2ms/step - loss: 5.0956 - y1_output_loss: 1.5984 - y2_output_loss: 3.4971 - y1_output_root_mean_squared_error: 1.2643 - y2_output_root_mean_squared_error: 1.8701 - val_loss: 4.4438 - val_y1_output_loss: 1.3513 - val_y2_output_loss: 3.0925 - val_y1_output_root_mean_squared_error: 1.1624 - val_y2_output_root_mean_squared_error: 1.7586
# Epoch 60/500
# 62/62 [==============================] - 0s 1ms/step - loss: 5.5452 - y1_output_loss: 1.6232 - y2_output_loss: 3.9219 - y1_output_root_mean_squared_error: 1.2741 - y2_output_root_mean_squared_error: 1.9804 - val_loss: 4.4282 - val_y1_output_loss: 1.5040 - val_y2_output_loss: 2.9242 - val_y1_output_root_mean_squared_error: 1.2264 - val_y2_output_root_mean_squared_error: 1.7100
# Epoch 61/500
# 62/62 [==============================] - 0s 2ms/step - loss: 5.6325 - y1_output_loss: 1.6498 - y2_output_loss: 3.9827 - y1_output_root_mean_squared_error: 1.2844 - y2_output_root_mean_squared_error: 1.9957 - val_loss: 4.6733 - val_y1_output_loss: 1.4715 - val_y2_output_loss: 3.2018 - val_y1_output_root_mean_squared_error: 1.2130 - val_y2_output_root_mean_squared_error: 1.7894
# Epoch 62/500
# 62/62 [==============================] - 0s 1ms/step - loss: 5.6916 - y1_output_loss: 1.6273 - y2_output_loss: 4.0643 - y1_output_root_mean_squared_error: 1.2757 - y2_output_root_mean_squared_error: 2.0160 - val_loss: 3.8875 - val_y1_output_loss: 1.0073 - val_y2_output_loss: 2.8802 - val_y1_output_root_mean_squared_error: 1.0037 - val_y2_output_root_mean_squared_error: 1.6971
# Epoch 63/500
# 62/62 [==============================] - 0s 1ms/step - loss: 5.1524 - y1_output_loss: 1.4449 - y2_output_loss: 3.7074 - y1_output_root_mean_squared_error: 1.2021 - y2_output_root_mean_squared_error: 1.9255 - val_loss: 4.1412 - val_y1_output_loss: 1.2173 - val_y2_output_loss: 2.9239 - val_y1_output_root_mean_squared_error: 1.1033 - val_y2_output_root_mean_squared_error: 1.7099
# Epoch 64/500
# 62/62 [==============================] - 0s 2ms/step - loss: 6.2345 - y1_output_loss: 1.7979 - y2_output_loss: 4.4366 - y1_output_root_mean_squared_error: 1.3408 - y2_output_root_mean_squared_error: 2.1063 - val_loss: 5.5431 - val_y1_output_loss: 0.8692 - val_y2_output_loss: 4.6739 - val_y1_output_root_mean_squared_error: 0.9323 - val_y2_output_root_mean_squared_error: 2.1619
# Epoch 65/500
# 62/62 [==============================] - 0s 3ms/step - loss: 4.8104 - y1_output_loss: 1.3320 - y2_output_loss: 3.4784 - y1_output_root_mean_squared_error: 1.1541 - y2_output_root_mean_squared_error: 1.8651 - val_loss: 7.0390 - val_y1_output_loss: 1.0916 - val_y2_output_loss: 5.9474 - val_y1_output_root_mean_squared_error: 1.0448 - val_y2_output_root_mean_squared_error: 2.4387
# Epoch 66/500
# 62/62 [==============================] - 0s 2ms/step - loss: 4.7836 - y1_output_loss: 1.2270 - y2_output_loss: 3.5566 - y1_output_root_mean_squared_error: 1.1077 - y2_output_root_mean_squared_error: 1.8859 - val_loss: 5.2839 - val_y1_output_loss: 1.2799 - val_y2_output_loss: 4.0040 - val_y1_output_root_mean_squared_error: 1.1313 - val_y2_output_root_mean_squared_error: 2.0010
# Epoch 67/500
# 62/62 [==============================] - 0s 1ms/step - loss: 8.8536 - y1_output_loss: 2.4535 - y2_output_loss: 6.4001 - y1_output_root_mean_squared_error: 1.5664 - y2_output_root_mean_squared_error: 2.5298 - val_loss: 4.4740 - val_y1_output_loss: 0.7076 - val_y2_output_loss: 3.7664 - val_y1_output_root_mean_squared_error: 0.8412 - val_y2_output_root_mean_squared_error: 1.9407
# Epoch 68/500
# 62/62 [==============================] - 0s 1ms/step - loss: 4.0123 - y1_output_loss: 1.0580 - y2_output_loss: 2.9543 - y1_output_root_mean_squared_error: 1.0286 - y2_output_root_mean_squared_error: 1.7188 - val_loss: 20.9033 - val_y1_output_loss: 8.0860 - val_y2_output_loss: 12.8174 - val_y1_output_root_mean_squared_error: 2.8436 - val_y2_output_root_mean_squared_error: 3.5801
# Epoch 69/500
# 62/62 [==============================] - 0s 2ms/step - loss: 5.5610 - y1_output_loss: 1.4855 - y2_output_loss: 4.0755 - y1_output_root_mean_squared_error: 1.2188 - y2_output_root_mean_squared_error: 2.0188 - val_loss: 3.4927 - val_y1_output_loss: 0.9800 - val_y2_output_loss: 2.5127 - val_y1_output_root_mean_squared_error: 0.9899 - val_y2_output_root_mean_squared_error: 1.5851
# Epoch 70/500
# 62/62 [==============================] - 0s 3ms/step - loss: 5.1711 - y1_output_loss: 1.4338 - y2_output_loss: 3.7372 - y1_output_root_mean_squared_error: 1.1974 - y2_output_root_mean_squared_error: 1.9332 - val_loss: 4.8758 - val_y1_output_loss: 1.4650 - val_y2_output_loss: 3.4108 - val_y1_output_root_mean_squared_error: 1.2104 - val_y2_output_root_mean_squared_error: 1.8468
# Epoch 71/500
# 62/62 [==============================] - 0s 2ms/step - loss: 4.3202 - y1_output_loss: 1.1159 - y2_output_loss: 3.2043 - y1_output_root_mean_squared_error: 1.0564 - y2_output_root_mean_squared_error: 1.7901 - val_loss: 2.7720 - val_y1_output_loss: 0.5785 - val_y2_output_loss: 2.1935 - val_y1_output_root_mean_squared_error: 0.7606 - val_y2_output_root_mean_squared_error: 1.4811
# Epoch 72/500
# 62/62 [==============================] - 0s 1ms/step - loss: 3.3758 - y1_output_loss: 0.7845 - y2_output_loss: 2.5913 - y1_output_root_mean_squared_error: 0.8857 - y2_output_root_mean_squared_error: 1.6098 - val_loss: 3.3975 - val_y1_output_loss: 0.8547 - val_y2_output_loss: 2.5428 - val_y1_output_root_mean_squared_error: 0.9245 - val_y2_output_root_mean_squared_error: 1.5946
# Epoch 73/500
# 62/62 [==============================] - 0s 1ms/step - loss: 3.6120 - y1_output_loss: 0.9615 - y2_output_loss: 2.6505 - y1_output_root_mean_squared_error: 0.9806 - y2_output_root_mean_squared_error: 1.6280 - val_loss: 10.8140 - val_y1_output_loss: 1.2199 - val_y2_output_loss: 9.5941 - val_y1_output_root_mean_squared_error: 1.1045 - val_y2_output_root_mean_squared_error: 3.0974
# Epoch 74/500
# 62/62 [==============================] - 0s 2ms/step - loss: 5.2808 - y1_output_loss: 1.3681 - y2_output_loss: 3.9127 - y1_output_root_mean_squared_error: 1.1697 - y2_output_root_mean_squared_error: 1.9781 - val_loss: 5.9000 - val_y1_output_loss: 2.7564 - val_y2_output_loss: 3.1437 - val_y1_output_root_mean_squared_error: 1.6602 - val_y2_output_root_mean_squared_error: 1.7730
# Epoch 75/500
# 62/62 [==============================] - 0s 1ms/step - loss: 3.8795 - y1_output_loss: 1.0013 - y2_output_loss: 2.8783 - y1_output_root_mean_squared_error: 1.0006 - y2_output_root_mean_squared_error: 1.6965 - val_loss: 3.2023 - val_y1_output_loss: 0.6125 - val_y2_output_loss: 2.5898 - val_y1_output_root_mean_squared_error: 0.7826 - val_y2_output_root_mean_squared_error: 1.6093
# Epoch 76/500
# 62/62 [==============================] - 0s 1ms/step - loss: 4.3086 - y1_output_loss: 1.0935 - y2_output_loss: 3.2152 - y1_output_root_mean_squared_error: 1.0457 - y2_output_root_mean_squared_error: 1.7931 - val_loss: 4.6794 - val_y1_output_loss: 0.8063 - val_y2_output_loss: 3.8731 - val_y1_output_root_mean_squared_error: 0.8979 - val_y2_output_root_mean_squared_error: 1.9680
# Epoch 77/500
# 62/62 [==============================] - 0s 1ms/step - loss: 5.7486 - y1_output_loss: 1.6118 - y2_output_loss: 4.1369 - y1_output_root_mean_squared_error: 1.2696 - y2_output_root_mean_squared_error: 2.0339 - val_loss: 4.6831 - val_y1_output_loss: 1.6022 - val_y2_output_loss: 3.0808 - val_y1_output_root_mean_squared_error: 1.2658 - val_y2_output_root_mean_squared_error: 1.7552
# Epoch 78/500
# 62/62 [==============================] - 0s 1ms/step - loss: 3.9482 - y1_output_loss: 0.9287 - y2_output_loss: 3.0195 - y1_output_root_mean_squared_error: 0.9637 - y2_output_root_mean_squared_error: 1.7377 - val_loss: 2.5213 - val_y1_output_loss: 0.4484 - val_y2_output_loss: 2.0728 - val_y1_output_root_mean_squared_error: 0.6696 - val_y2_output_root_mean_squared_error: 1.4397
# Epoch 79/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.0902 - y1_output_loss: 0.7180 - y2_output_loss: 2.3722 - y1_output_root_mean_squared_error: 0.8474 - y2_output_root_mean_squared_error: 1.5402 - val_loss: 3.7865 - val_y1_output_loss: 0.6078 - val_y2_output_loss: 3.1787 - val_y1_output_root_mean_squared_error: 0.7796 - val_y2_output_root_mean_squared_error: 1.7829
# Epoch 80/500
# 62/62 [==============================] - 0s 2ms/step - loss: 4.2412 - y1_output_loss: 0.9564 - y2_output_loss: 3.2848 - y1_output_root_mean_squared_error: 0.9780 - y2_output_root_mean_squared_error: 1.8124 - val_loss: 2.6827 - val_y1_output_loss: 0.6242 - val_y2_output_loss: 2.0586 - val_y1_output_root_mean_squared_error: 0.7900 - val_y2_output_root_mean_squared_error: 1.4348
# Epoch 81/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.0668 - y1_output_loss: 0.6703 - y2_output_loss: 2.3964 - y1_output_root_mean_squared_error: 0.8187 - y2_output_root_mean_squared_error: 1.5480 - val_loss: 11.2742 - val_y1_output_loss: 2.6878 - val_y2_output_loss: 8.5863 - val_y1_output_root_mean_squared_error: 1.6395 - val_y2_output_root_mean_squared_error: 2.9302
# Epoch 82/500
# 62/62 [==============================] - 0s 1ms/step - loss: 4.3916 - y1_output_loss: 0.9896 - y2_output_loss: 3.4019 - y1_output_root_mean_squared_error: 0.9948 - y2_output_root_mean_squared_error: 1.8444 - val_loss: 3.7451 - val_y1_output_loss: 0.9505 - val_y2_output_loss: 2.7946 - val_y1_output_root_mean_squared_error: 0.9749 - val_y2_output_root_mean_squared_error: 1.6717
# Epoch 83/500
# 62/62 [==============================] - 0s 1ms/step - loss: 2.8911 - y1_output_loss: 0.7284 - y2_output_loss: 2.1628 - y1_output_root_mean_squared_error: 0.8534 - y2_output_root_mean_squared_error: 1.4706 - val_loss: 3.6571 - val_y1_output_loss: 0.5177 - val_y2_output_loss: 3.1394 - val_y1_output_root_mean_squared_error: 0.7195 - val_y2_output_root_mean_squared_error: 1.7718
# Epoch 84/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.9937 - y1_output_loss: 0.6190 - y2_output_loss: 2.3747 - y1_output_root_mean_squared_error: 0.7868 - y2_output_root_mean_squared_error: 1.5410 - val_loss: 3.9040 - val_y1_output_loss: 0.5825 - val_y2_output_loss: 3.3215 - val_y1_output_root_mean_squared_error: 0.7632 - val_y2_output_root_mean_squared_error: 1.8225
# Epoch 85/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.7127 - y1_output_loss: 0.6064 - y2_output_loss: 2.1063 - y1_output_root_mean_squared_error: 0.7787 - y2_output_root_mean_squared_error: 1.4513 - val_loss: 5.1662 - val_y1_output_loss: 1.1997 - val_y2_output_loss: 3.9665 - val_y1_output_root_mean_squared_error: 1.0953 - val_y2_output_root_mean_squared_error: 1.9916
# Epoch 86/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.0787 - y1_output_loss: 0.7437 - y2_output_loss: 2.3350 - y1_output_root_mean_squared_error: 0.8624 - y2_output_root_mean_squared_error: 1.5281 - val_loss: 13.3202 - val_y1_output_loss: 3.5741 - val_y2_output_loss: 9.7461 - val_y1_output_root_mean_squared_error: 1.8905 - val_y2_output_root_mean_squared_error: 3.1219
# Epoch 87/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.9592 - y1_output_loss: 0.9347 - y2_output_loss: 3.0246 - y1_output_root_mean_squared_error: 0.9668 - y2_output_root_mean_squared_error: 1.7391 - val_loss: 2.9065 - val_y1_output_loss: 0.6236 - val_y2_output_loss: 2.2829 - val_y1_output_root_mean_squared_error: 0.7897 - val_y2_output_root_mean_squared_error: 1.5109
# Epoch 88/500
# 62/62 [==============================] - 0s 3ms/step - loss: 3.1739 - y1_output_loss: 0.7882 - y2_output_loss: 2.3858 - y1_output_root_mean_squared_error: 0.8878 - y2_output_root_mean_squared_error: 1.5446 - val_loss: 2.3312 - val_y1_output_loss: 0.4150 - val_y2_output_loss: 1.9161 - val_y1_output_root_mean_squared_error: 0.6442 - val_y2_output_root_mean_squared_error: 1.3842
# Epoch 89/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.8593 - y1_output_loss: 0.6673 - y2_output_loss: 2.1920 - y1_output_root_mean_squared_error: 0.8169 - y2_output_root_mean_squared_error: 1.4805 - val_loss: 4.7319 - val_y1_output_loss: 1.3376 - val_y2_output_loss: 3.3943 - val_y1_output_root_mean_squared_error: 1.1565 - val_y2_output_root_mean_squared_error: 1.8424
# Epoch 90/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.9985 - y1_output_loss: 0.6715 - y2_output_loss: 2.3270 - y1_output_root_mean_squared_error: 0.8194 - y2_output_root_mean_squared_error: 1.5254 - val_loss: 2.5262 - val_y1_output_loss: 0.6059 - val_y2_output_loss: 1.9203 - val_y1_output_root_mean_squared_error: 0.7784 - val_y2_output_root_mean_squared_error: 1.3858
# Epoch 91/500
# 62/62 [==============================] - 0s 3ms/step - loss: 5.5150 - y1_output_loss: 1.3892 - y2_output_loss: 4.1258 - y1_output_root_mean_squared_error: 1.1786 - y2_output_root_mean_squared_error: 2.0312 - val_loss: 4.5720 - val_y1_output_loss: 0.8403 - val_y2_output_loss: 3.7316 - val_y1_output_root_mean_squared_error: 0.9167 - val_y2_output_root_mean_squared_error: 1.9317
# Epoch 92/500
# 62/62 [==============================] - 0s 3ms/step - loss: 3.3340 - y1_output_loss: 0.7815 - y2_output_loss: 2.5525 - y1_output_root_mean_squared_error: 0.8840 - y2_output_root_mean_squared_error: 1.5977 - val_loss: 7.5944 - val_y1_output_loss: 0.6685 - val_y2_output_loss: 6.9260 - val_y1_output_root_mean_squared_error: 0.8176 - val_y2_output_root_mean_squared_error: 2.6317
# Epoch 93/500
# 62/62 [==============================] - 0s 1ms/step - loss: 3.0645 - y1_output_loss: 0.6572 - y2_output_loss: 2.4072 - y1_output_root_mean_squared_error: 0.8107 - y2_output_root_mean_squared_error: 1.5515 - val_loss: 2.4160 - val_y1_output_loss: 0.5201 - val_y2_output_loss: 1.8959 - val_y1_output_root_mean_squared_error: 0.7212 - val_y2_output_root_mean_squared_error: 1.3769
# Epoch 94/500
# 62/62 [==============================] - 0s 1ms/step - loss: 2.8967 - y1_output_loss: 0.5961 - y2_output_loss: 2.3007 - y1_output_root_mean_squared_error: 0.7720 - y2_output_root_mean_squared_error: 1.5168 - val_loss: 2.7990 - val_y1_output_loss: 0.8115 - val_y2_output_loss: 1.9876 - val_y1_output_root_mean_squared_error: 0.9008 - val_y2_output_root_mean_squared_error: 1.4098
# Epoch 95/500
# 62/62 [==============================] - 0s 1ms/step - loss: 2.7600 - y1_output_loss: 0.6498 - y2_output_loss: 2.1101 - y1_output_root_mean_squared_error: 0.8061 - y2_output_root_mean_squared_error: 1.4526 - val_loss: 4.7783 - val_y1_output_loss: 1.5437 - val_y2_output_loss: 3.2347 - val_y1_output_root_mean_squared_error: 1.2424 - val_y2_output_root_mean_squared_error: 1.7985
# Epoch 96/500
# 62/62 [==============================] - 0s 1ms/step - loss: 4.2896 - y1_output_loss: 1.1588 - y2_output_loss: 3.1308 - y1_output_root_mean_squared_error: 1.0765 - y2_output_root_mean_squared_error: 1.7694 - val_loss: 3.2974 - val_y1_output_loss: 0.9029 - val_y2_output_loss: 2.3945 - val_y1_output_root_mean_squared_error: 0.9502 - val_y2_output_root_mean_squared_error: 1.5474
# Epoch 97/500
# 62/62 [==============================] - 0s 1ms/step - loss: 2.6671 - y1_output_loss: 0.6129 - y2_output_loss: 2.0542 - y1_output_root_mean_squared_error: 0.7829 - y2_output_root_mean_squared_error: 1.4332 - val_loss: 2.1098 - val_y1_output_loss: 0.4731 - val_y2_output_loss: 1.6367 - val_y1_output_root_mean_squared_error: 0.6878 - val_y2_output_root_mean_squared_error: 1.2793
# Epoch 98/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.6884 - y1_output_loss: 0.5920 - y2_output_loss: 2.0964 - y1_output_root_mean_squared_error: 0.7694 - y2_output_root_mean_squared_error: 1.4479 - val_loss: 9.7633 - val_y1_output_loss: 0.8774 - val_y2_output_loss: 8.8859 - val_y1_output_root_mean_squared_error: 0.9367 - val_y2_output_root_mean_squared_error: 2.9809
# Epoch 99/500
# 62/62 [==============================] - 0s 1ms/step - loss: 6.0486 - y1_output_loss: 1.5947 - y2_output_loss: 4.4539 - y1_output_root_mean_squared_error: 1.2628 - y2_output_root_mean_squared_error: 2.1104 - val_loss: 2.1157 - val_y1_output_loss: 0.3646 - val_y2_output_loss: 1.7511 - val_y1_output_root_mean_squared_error: 0.6038 - val_y2_output_root_mean_squared_error: 1.3233
# Epoch 100/500
# 62/62 [==============================] - 0s 1ms/step - loss: 10.7607 - y1_output_loss: 3.0896 - y2_output_loss: 7.6710 - y1_output_root_mean_squared_error: 1.7577 - y2_output_root_mean_squared_error: 2.7697 - val_loss: 2.3788 - val_y1_output_loss: 0.5788 - val_y2_output_loss: 1.8000 - val_y1_output_root_mean_squared_error: 0.7608 - val_y2_output_root_mean_squared_error: 1.3416
# Epoch 101/500
# 62/62 [==============================] - 0s 1ms/step - loss: 2.5426 - y1_output_loss: 0.6000 - y2_output_loss: 1.9427 - y1_output_root_mean_squared_error: 0.7746 - y2_output_root_mean_squared_error: 1.3938 - val_loss: 9.4791 - val_y1_output_loss: 4.5816 - val_y2_output_loss: 4.8975 - val_y1_output_root_mean_squared_error: 2.1405 - val_y2_output_root_mean_squared_error: 2.2130
# Epoch 102/500
# 62/62 [==============================] - 0s 1ms/step - loss: 3.0165 - y1_output_loss: 0.6667 - y2_output_loss: 2.3498 - y1_output_root_mean_squared_error: 0.8165 - y2_output_root_mean_squared_error: 1.5329 - val_loss: 19.8328 - val_y1_output_loss: 6.5353 - val_y2_output_loss: 13.2974 - val_y1_output_root_mean_squared_error: 2.5564 - val_y2_output_root_mean_squared_error: 3.6466
# Epoch 103/500
# 62/62 [==============================] - 0s 1ms/step - loss: 3.1854 - y1_output_loss: 0.6794 - y2_output_loss: 2.5060 - y1_output_root_mean_squared_error: 0.8243 - y2_output_root_mean_squared_error: 1.5830 - val_loss: 6.9272 - val_y1_output_loss: 1.4539 - val_y2_output_loss: 5.4733 - val_y1_output_root_mean_squared_error: 1.2058 - val_y2_output_root_mean_squared_error: 2.3395
# Epoch 104/500
# 62/62 [==============================] - 0s 1ms/step - loss: 2.7771 - y1_output_loss: 0.6402 - y2_output_loss: 2.1369 - y1_output_root_mean_squared_error: 0.8001 - y2_output_root_mean_squared_error: 1.4618 - val_loss: 4.4309 - val_y1_output_loss: 0.9992 - val_y2_output_loss: 3.4317 - val_y1_output_root_mean_squared_error: 0.9996 - val_y2_output_root_mean_squared_error: 1.8525
# Epoch 105/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.0640 - y1_output_loss: 0.4686 - y2_output_loss: 1.5955 - y1_output_root_mean_squared_error: 0.6845 - y2_output_root_mean_squared_error: 1.2631 - val_loss: 2.5628 - val_y1_output_loss: 0.3639 - val_y2_output_loss: 2.1990 - val_y1_output_root_mean_squared_error: 0.6032 - val_y2_output_root_mean_squared_error: 1.4829
# Epoch 106/500
# 62/62 [==============================] - 0s 1ms/step - loss: 2.5751 - y1_output_loss: 0.5422 - y2_output_loss: 2.0330 - y1_output_root_mean_squared_error: 0.7363 - y2_output_root_mean_squared_error: 1.4258 - val_loss: 2.0153 - val_y1_output_loss: 0.3693 - val_y2_output_loss: 1.6459 - val_y1_output_root_mean_squared_error: 0.6077 - val_y2_output_root_mean_squared_error: 1.2829
# Epoch 107/500
# 62/62 [==============================] - 0s 1ms/step - loss: 2.3358 - y1_output_loss: 0.4860 - y2_output_loss: 1.8498 - y1_output_root_mean_squared_error: 0.6972 - y2_output_root_mean_squared_error: 1.3601 - val_loss: 2.5220 - val_y1_output_loss: 0.5705 - val_y2_output_loss: 1.9516 - val_y1_output_root_mean_squared_error: 0.7553 - val_y2_output_root_mean_squared_error: 1.3970
# Epoch 108/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.4476 - y1_output_loss: 0.5364 - y2_output_loss: 1.9112 - y1_output_root_mean_squared_error: 0.7324 - y2_output_root_mean_squared_error: 1.3825 - val_loss: 2.7691 - val_y1_output_loss: 0.6951 - val_y2_output_loss: 2.0740 - val_y1_output_root_mean_squared_error: 0.8337 - val_y2_output_root_mean_squared_error: 1.4401
# Epoch 109/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.1131 - y1_output_loss: 0.4421 - y2_output_loss: 1.6710 - y1_output_root_mean_squared_error: 0.6649 - y2_output_root_mean_squared_error: 1.2927 - val_loss: 2.3599 - val_y1_output_loss: 0.4072 - val_y2_output_loss: 1.9526 - val_y1_output_root_mean_squared_error: 0.6381 - val_y2_output_root_mean_squared_error: 1.3974
# Epoch 110/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.6582 - y1_output_loss: 0.5391 - y2_output_loss: 2.1191 - y1_output_root_mean_squared_error: 0.7342 - y2_output_root_mean_squared_error: 1.4557 - val_loss: 2.2143 - val_y1_output_loss: 0.5006 - val_y2_output_loss: 1.7137 - val_y1_output_root_mean_squared_error: 0.7075 - val_y2_output_root_mean_squared_error: 1.3091
# Epoch 111/500
# 62/62 [==============================] - 0s 1ms/step - loss: 4.5055 - y1_output_loss: 1.4233 - y2_output_loss: 3.0822 - y1_output_root_mean_squared_error: 1.1930 - y2_output_root_mean_squared_error: 1.7556 - val_loss: 3.1464 - val_y1_output_loss: 0.7706 - val_y2_output_loss: 2.3758 - val_y1_output_root_mean_squared_error: 0.8779 - val_y2_output_root_mean_squared_error: 1.5414
# Epoch 112/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.7995 - y1_output_loss: 0.6254 - y2_output_loss: 2.1742 - y1_output_root_mean_squared_error: 0.7908 - y2_output_root_mean_squared_error: 1.4745 - val_loss: 2.7726 - val_y1_output_loss: 0.6241 - val_y2_output_loss: 2.1484 - val_y1_output_root_mean_squared_error: 0.7900 - val_y2_output_root_mean_squared_error: 1.4658
# Epoch 113/500
# 62/62 [==============================] - 0s 1ms/step - loss: 2.1789 - y1_output_loss: 0.4763 - y2_output_loss: 1.7026 - y1_output_root_mean_squared_error: 0.6902 - y2_output_root_mean_squared_error: 1.3048 - val_loss: 2.1711 - val_y1_output_loss: 0.3940 - val_y2_output_loss: 1.7772 - val_y1_output_root_mean_squared_error: 0.6277 - val_y2_output_root_mean_squared_error: 1.3331
# Epoch 114/500
# 62/62 [==============================] - 0s 1ms/step - loss: 3.2361 - y1_output_loss: 0.7411 - y2_output_loss: 2.4951 - y1_output_root_mean_squared_error: 0.8608 - y2_output_root_mean_squared_error: 1.5796 - val_loss: 4.8387 - val_y1_output_loss: 1.8566 - val_y2_output_loss: 2.9820 - val_y1_output_root_mean_squared_error: 1.3626 - val_y2_output_root_mean_squared_error: 1.7268
# Epoch 115/500
# 62/62 [==============================] - 0s 1ms/step - loss: 2.3632 - y1_output_loss: 0.5548 - y2_output_loss: 1.8084 - y1_output_root_mean_squared_error: 0.7449 - y2_output_root_mean_squared_error: 1.3448 - val_loss: 2.8669 - val_y1_output_loss: 0.6100 - val_y2_output_loss: 2.2569 - val_y1_output_root_mean_squared_error: 0.7810 - val_y2_output_root_mean_squared_error: 1.5023
# Epoch 116/500
# 62/62 [==============================] - 0s 1ms/step - loss: 2.0172 - y1_output_loss: 0.4646 - y2_output_loss: 1.5526 - y1_output_root_mean_squared_error: 0.6816 - y2_output_root_mean_squared_error: 1.2460 - val_loss: 2.2163 - val_y1_output_loss: 0.5923 - val_y2_output_loss: 1.6239 - val_y1_output_root_mean_squared_error: 0.7696 - val_y2_output_root_mean_squared_error: 1.2743
# Epoch 117/500
# 62/62 [==============================] - 0s 1ms/step - loss: 2.2228 - y1_output_loss: 0.4942 - y2_output_loss: 1.7286 - y1_output_root_mean_squared_error: 0.7030 - y2_output_root_mean_squared_error: 1.3148 - val_loss: 3.1085 - val_y1_output_loss: 0.8809 - val_y2_output_loss: 2.2276 - val_y1_output_root_mean_squared_error: 0.9386 - val_y2_output_root_mean_squared_error: 1.4925
# Epoch 118/500
# 62/62 [==============================] - 0s 1ms/step - loss: 3.7724 - y1_output_loss: 0.8602 - y2_output_loss: 2.9122 - y1_output_root_mean_squared_error: 0.9275 - y2_output_root_mean_squared_error: 1.7065 - val_loss: 2.2506 - val_y1_output_loss: 0.6168 - val_y2_output_loss: 1.6338 - val_y1_output_root_mean_squared_error: 0.7854 - val_y2_output_root_mean_squared_error: 1.2782
# Epoch 119/500
# 62/62 [==============================] - 0s 1ms/step - loss: 2.1679 - y1_output_loss: 0.5174 - y2_output_loss: 1.6505 - y1_output_root_mean_squared_error: 0.7193 - y2_output_root_mean_squared_error: 1.2847 - val_loss: 1.9544 - val_y1_output_loss: 0.3772 - val_y2_output_loss: 1.5772 - val_y1_output_root_mean_squared_error: 0.6142 - val_y2_output_root_mean_squared_error: 1.2559
# Epoch 120/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.1974 - y1_output_loss: 0.4729 - y2_output_loss: 1.7246 - y1_output_root_mean_squared_error: 0.6877 - y2_output_root_mean_squared_error: 1.3132 - val_loss: 2.0721 - val_y1_output_loss: 0.3235 - val_y2_output_loss: 1.7486 - val_y1_output_root_mean_squared_error: 0.5688 - val_y2_output_root_mean_squared_error: 1.3223
# Epoch 121/500
# 62/62 [==============================] - 0s 1ms/step - loss: 4.2410 - y1_output_loss: 1.0220 - y2_output_loss: 3.2190 - y1_output_root_mean_squared_error: 1.0109 - y2_output_root_mean_squared_error: 1.7942 - val_loss: 1.9571 - val_y1_output_loss: 0.2988 - val_y2_output_loss: 1.6583 - val_y1_output_root_mean_squared_error: 0.5467 - val_y2_output_root_mean_squared_error: 1.2878
# Epoch 122/500
# 62/62 [==============================] - 0s 1ms/step - loss: 1.9021 - y1_output_loss: 0.3668 - y2_output_loss: 1.5353 - y1_output_root_mean_squared_error: 0.6056 - y2_output_root_mean_squared_error: 1.2391 - val_loss: 2.0693 - val_y1_output_loss: 0.3836 - val_y2_output_loss: 1.6857 - val_y1_output_root_mean_squared_error: 0.6194 - val_y2_output_root_mean_squared_error: 1.2983
# Epoch 123/500
# ...
# Epoch 461/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4340 - y1_output_loss: 0.1322 - y2_output_loss: 0.3018 - y1_output_root_mean_squared_error: 0.3635 - y2_output_root_mean_squared_error: 0.5494 - val_loss: 0.9986 - val_y1_output_loss: 0.2363 - val_y2_output_loss: 0.7623 - val_y1_output_root_mean_squared_error: 0.4861 - val_y2_output_root_mean_squared_error: 0.8731
# Epoch 462/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5447 - y1_output_loss: 0.1397 - y2_output_loss: 0.4050 - y1_output_root_mean_squared_error: 0.3737 - y2_output_root_mean_squared_error: 0.6364 - val_loss: 0.7845 - val_y1_output_loss: 0.1621 - val_y2_output_loss: 0.6223 - val_y1_output_root_mean_squared_error: 0.4026 - val_y2_output_root_mean_squared_error: 0.7889
# Epoch 463/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.9747 - y1_output_loss: 0.2124 - y2_output_loss: 0.7623 - y1_output_root_mean_squared_error: 0.4609 - y2_output_root_mean_squared_error: 0.8731 - val_loss: 2.7411 - val_y1_output_loss: 0.5453 - val_y2_output_loss: 2.1958 - val_y1_output_root_mean_squared_error: 0.7384 - val_y2_output_root_mean_squared_error: 1.4818
# Epoch 464/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.7342 - y1_output_loss: 0.1837 - y2_output_loss: 0.5505 - y1_output_root_mean_squared_error: 0.4286 - y2_output_root_mean_squared_error: 0.7420 - val_loss: 1.4170 - val_y1_output_loss: 0.2811 - val_y2_output_loss: 1.1359 - val_y1_output_root_mean_squared_error: 0.5302 - val_y2_output_root_mean_squared_error: 1.0658
# Epoch 465/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5109 - y1_output_loss: 0.1452 - y2_output_loss: 0.3656 - y1_output_root_mean_squared_error: 0.3811 - y2_output_root_mean_squared_error: 0.6047 - val_loss: 1.1792 - val_y1_output_loss: 0.1747 - val_y2_output_loss: 1.0044 - val_y1_output_root_mean_squared_error: 0.4180 - val_y2_output_root_mean_squared_error: 1.0022
# Epoch 466/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4243 - y1_output_loss: 0.1351 - y2_output_loss: 0.2892 - y1_output_root_mean_squared_error: 0.3676 - y2_output_root_mean_squared_error: 0.5378 - val_loss: 0.7726 - val_y1_output_loss: 0.1617 - val_y2_output_loss: 0.6109 - val_y1_output_root_mean_squared_error: 0.4021 - val_y2_output_root_mean_squared_error: 0.7816
# Epoch 467/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4269 - y1_output_loss: 0.1311 - y2_output_loss: 0.2958 - y1_output_root_mean_squared_error: 0.3620 - y2_output_root_mean_squared_error: 0.5439 - val_loss: 0.8076 - val_y1_output_loss: 0.1612 - val_y2_output_loss: 0.6464 - val_y1_output_root_mean_squared_error: 0.4015 - val_y2_output_root_mean_squared_error: 0.8040
# Epoch 468/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4114 - y1_output_loss: 0.1344 - y2_output_loss: 0.2769 - y1_output_root_mean_squared_error: 0.3667 - y2_output_root_mean_squared_error: 0.5263 - val_loss: 0.7396 - val_y1_output_loss: 0.1569 - val_y2_output_loss: 0.5828 - val_y1_output_root_mean_squared_error: 0.3961 - val_y2_output_root_mean_squared_error: 0.7634
# Epoch 469/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4675 - y1_output_loss: 0.1440 - y2_output_loss: 0.3236 - y1_output_root_mean_squared_error: 0.3795 - y2_output_root_mean_squared_error: 0.5688 - val_loss: 0.7316 - val_y1_output_loss: 0.1722 - val_y2_output_loss: 0.5593 - val_y1_output_root_mean_squared_error: 0.4150 - val_y2_output_root_mean_squared_error: 0.7479
# Epoch 470/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4024 - y1_output_loss: 0.1256 - y2_output_loss: 0.2768 - y1_output_root_mean_squared_error: 0.3544 - y2_output_root_mean_squared_error: 0.5261 - val_loss: 1.0784 - val_y1_output_loss: 0.1504 - val_y2_output_loss: 0.9279 - val_y1_output_root_mean_squared_error: 0.3879 - val_y2_output_root_mean_squared_error: 0.9633
# Epoch 471/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5456 - y1_output_loss: 0.1506 - y2_output_loss: 0.3950 - y1_output_root_mean_squared_error: 0.3881 - y2_output_root_mean_squared_error: 0.6285 - val_loss: 0.7043 - val_y1_output_loss: 0.1631 - val_y2_output_loss: 0.5412 - val_y1_output_root_mean_squared_error: 0.4038 - val_y2_output_root_mean_squared_error: 0.7356
# Epoch 472/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3599 - y1_output_loss: 0.1217 - y2_output_loss: 0.2382 - y1_output_root_mean_squared_error: 0.3489 - y2_output_root_mean_squared_error: 0.4881 - val_loss: 0.7057 - val_y1_output_loss: 0.1472 - val_y2_output_loss: 0.5585 - val_y1_output_root_mean_squared_error: 0.3837 - val_y2_output_root_mean_squared_error: 0.7473
# Epoch 473/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3598 - y1_output_loss: 0.1271 - y2_output_loss: 0.2327 - y1_output_root_mean_squared_error: 0.3564 - y2_output_root_mean_squared_error: 0.4824 - val_loss: 0.8508 - val_y1_output_loss: 0.2340 - val_y2_output_loss: 0.6168 - val_y1_output_root_mean_squared_error: 0.4837 - val_y2_output_root_mean_squared_error: 0.7854
# Epoch 474/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4709 - y1_output_loss: 0.1304 - y2_output_loss: 0.3405 - y1_output_root_mean_squared_error: 0.3611 - y2_output_root_mean_squared_error: 0.5835 - val_loss: 0.9767 - val_y1_output_loss: 0.1634 - val_y2_output_loss: 0.8134 - val_y1_output_root_mean_squared_error: 0.4042 - val_y2_output_root_mean_squared_error: 0.9019
# Epoch 475/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4545 - y1_output_loss: 0.1223 - y2_output_loss: 0.3322 - y1_output_root_mean_squared_error: 0.3498 - y2_output_root_mean_squared_error: 0.5763 - val_loss: 1.1008 - val_y1_output_loss: 0.1793 - val_y2_output_loss: 0.9215 - val_y1_output_root_mean_squared_error: 0.4235 - val_y2_output_root_mean_squared_error: 0.9599
# Epoch 476/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4825 - y1_output_loss: 0.1480 - y2_output_loss: 0.3346 - y1_output_root_mean_squared_error: 0.3847 - y2_output_root_mean_squared_error: 0.5784 - val_loss: 1.1000 - val_y1_output_loss: 0.3581 - val_y2_output_loss: 0.7419 - val_y1_output_root_mean_squared_error: 0.5984 - val_y2_output_root_mean_squared_error: 0.8613
# Epoch 477/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4646 - y1_output_loss: 0.1417 - y2_output_loss: 0.3228 - y1_output_root_mean_squared_error: 0.3765 - y2_output_root_mean_squared_error: 0.5682 - val_loss: 0.8582 - val_y1_output_loss: 0.2195 - val_y2_output_loss: 0.6387 - val_y1_output_root_mean_squared_error: 0.4685 - val_y2_output_root_mean_squared_error: 0.7992
# Epoch 478/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.3824 - y1_output_loss: 0.1130 - y2_output_loss: 0.2694 - y1_output_root_mean_squared_error: 0.3362 - y2_output_root_mean_squared_error: 0.5190 - val_loss: 0.9199 - val_y1_output_loss: 0.2492 - val_y2_output_loss: 0.6707 - val_y1_output_root_mean_squared_error: 0.4992 - val_y2_output_root_mean_squared_error: 0.8190
# Epoch 479/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4237 - y1_output_loss: 0.1227 - y2_output_loss: 0.3010 - y1_output_root_mean_squared_error: 0.3503 - y2_output_root_mean_squared_error: 0.5486 - val_loss: 0.8295 - val_y1_output_loss: 0.1377 - val_y2_output_loss: 0.6918 - val_y1_output_root_mean_squared_error: 0.3711 - val_y2_output_root_mean_squared_error: 0.8317
# Epoch 480/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.3920 - y1_output_loss: 0.1306 - y2_output_loss: 0.2614 - y1_output_root_mean_squared_error: 0.3613 - y2_output_root_mean_squared_error: 0.5113 - val_loss: 1.1195 - val_y1_output_loss: 0.2067 - val_y2_output_loss: 0.9128 - val_y1_output_root_mean_squared_error: 0.4547 - val_y2_output_root_mean_squared_error: 0.9554
# Epoch 481/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.3970 - y1_output_loss: 0.1289 - y2_output_loss: 0.2681 - y1_output_root_mean_squared_error: 0.3590 - y2_output_root_mean_squared_error: 0.5178 - val_loss: 0.8281 - val_y1_output_loss: 0.2181 - val_y2_output_loss: 0.6100 - val_y1_output_root_mean_squared_error: 0.4670 - val_y2_output_root_mean_squared_error: 0.7810
# Epoch 482/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4265 - y1_output_loss: 0.1251 - y2_output_loss: 0.3013 - y1_output_root_mean_squared_error: 0.3538 - y2_output_root_mean_squared_error: 0.5490 - val_loss: 0.7460 - val_y1_output_loss: 0.1454 - val_y2_output_loss: 0.6007 - val_y1_output_root_mean_squared_error: 0.3813 - val_y2_output_root_mean_squared_error: 0.7750
# Epoch 483/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.3472 - y1_output_loss: 0.1230 - y2_output_loss: 0.2242 - y1_output_root_mean_squared_error: 0.3507 - y2_output_root_mean_squared_error: 0.4735 - val_loss: 0.7093 - val_y1_output_loss: 0.1577 - val_y2_output_loss: 0.5516 - val_y1_output_root_mean_squared_error: 0.3971 - val_y2_output_root_mean_squared_error: 0.7427
# Epoch 484/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4612 - y1_output_loss: 0.1280 - y2_output_loss: 0.3331 - y1_output_root_mean_squared_error: 0.3578 - y2_output_root_mean_squared_error: 0.5772 - val_loss: 1.6769 - val_y1_output_loss: 0.2996 - val_y2_output_loss: 1.3773 - val_y1_output_root_mean_squared_error: 0.5474 - val_y2_output_root_mean_squared_error: 1.1736
# Epoch 485/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5159 - y1_output_loss: 0.1269 - y2_output_loss: 0.3890 - y1_output_root_mean_squared_error: 0.3562 - y2_output_root_mean_squared_error: 0.6237 - val_loss: 0.8121 - val_y1_output_loss: 0.1918 - val_y2_output_loss: 0.6203 - val_y1_output_root_mean_squared_error: 0.4380 - val_y2_output_root_mean_squared_error: 0.7876
# Epoch 486/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4698 - y1_output_loss: 0.1306 - y2_output_loss: 0.3392 - y1_output_root_mean_squared_error: 0.3613 - y2_output_root_mean_squared_error: 0.5824 - val_loss: 0.6941 - val_y1_output_loss: 0.1489 - val_y2_output_loss: 0.5451 - val_y1_output_root_mean_squared_error: 0.3859 - val_y2_output_root_mean_squared_error: 0.7383
# Epoch 487/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5374 - y1_output_loss: 0.1415 - y2_output_loss: 0.3959 - y1_output_root_mean_squared_error: 0.3762 - y2_output_root_mean_squared_error: 0.6292 - val_loss: 1.7514 - val_y1_output_loss: 0.3459 - val_y2_output_loss: 1.4055 - val_y1_output_root_mean_squared_error: 0.5881 - val_y2_output_root_mean_squared_error: 1.1855
# Epoch 488/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.3728 - y1_output_loss: 0.1261 - y2_output_loss: 0.2466 - y1_output_root_mean_squared_error: 0.3552 - y2_output_root_mean_squared_error: 0.4966 - val_loss: 0.8017 - val_y1_output_loss: 0.2322 - val_y2_output_loss: 0.5695 - val_y1_output_root_mean_squared_error: 0.4818 - val_y2_output_root_mean_squared_error: 0.7547
# Epoch 489/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.3913 - y1_output_loss: 0.1195 - y2_output_loss: 0.2718 - y1_output_root_mean_squared_error: 0.3457 - y2_output_root_mean_squared_error: 0.5213 - val_loss: 1.0179 - val_y1_output_loss: 0.1476 - val_y2_output_loss: 0.8703 - val_y1_output_root_mean_squared_error: 0.3842 - val_y2_output_root_mean_squared_error: 0.9329
# Epoch 490/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.3761 - y1_output_loss: 0.1297 - y2_output_loss: 0.2464 - y1_output_root_mean_squared_error: 0.3602 - y2_output_root_mean_squared_error: 0.4964 - val_loss: 1.1256 - val_y1_output_loss: 0.1586 - val_y2_output_loss: 0.9670 - val_y1_output_root_mean_squared_error: 0.3983 - val_y2_output_root_mean_squared_error: 0.9834
# Epoch 491/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.3596 - y1_output_loss: 0.1160 - y2_output_loss: 0.2436 - y1_output_root_mean_squared_error: 0.3406 - y2_output_root_mean_squared_error: 0.4935 - val_loss: 0.8731 - val_y1_output_loss: 0.1539 - val_y2_output_loss: 0.7192 - val_y1_output_root_mean_squared_error: 0.3922 - val_y2_output_root_mean_squared_error: 0.8481
# Epoch 492/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4853 - y1_output_loss: 0.1263 - y2_output_loss: 0.3590 - y1_output_root_mean_squared_error: 0.3554 - y2_output_root_mean_squared_error: 0.5992 - val_loss: 0.7592 - val_y1_output_loss: 0.1640 - val_y2_output_loss: 0.5953 - val_y1_output_root_mean_squared_error: 0.4050 - val_y2_output_root_mean_squared_error: 0.7715
# Epoch 493/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4628 - y1_output_loss: 0.1234 - y2_output_loss: 0.3394 - y1_output_root_mean_squared_error: 0.3513 - y2_output_root_mean_squared_error: 0.5826 - val_loss: 0.7015 - val_y1_output_loss: 0.1467 - val_y2_output_loss: 0.5547 - val_y1_output_root_mean_squared_error: 0.3831 - val_y2_output_root_mean_squared_error: 0.7448
# Epoch 494/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5222 - y1_output_loss: 0.1374 - y2_output_loss: 0.3848 - y1_output_root_mean_squared_error: 0.3707 - y2_output_root_mean_squared_error: 0.6203 - val_loss: 0.7886 - val_y1_output_loss: 0.1824 - val_y2_output_loss: 0.6061 - val_y1_output_root_mean_squared_error: 0.4271 - val_y2_output_root_mean_squared_error: 0.7785
# Epoch 495/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.3972 - y1_output_loss: 0.1278 - y2_output_loss: 0.2695 - y1_output_root_mean_squared_error: 0.3575 - y2_output_root_mean_squared_error: 0.5191 - val_loss: 0.9756 - val_y1_output_loss: 0.1968 - val_y2_output_loss: 0.7788 - val_y1_output_root_mean_squared_error: 0.4436 - val_y2_output_root_mean_squared_error: 0.8825
# Epoch 496/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.3489 - y1_output_loss: 0.1137 - y2_output_loss: 0.2352 - y1_output_root_mean_squared_error: 0.3371 - y2_output_root_mean_squared_error: 0.4850 - val_loss: 0.9765 - val_y1_output_loss: 0.2537 - val_y2_output_loss: 0.7227 - val_y1_output_root_mean_squared_error: 0.5037 - val_y2_output_root_mean_squared_error: 0.8501
# Epoch 497/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4342 - y1_output_loss: 0.1352 - y2_output_loss: 0.2990 - y1_output_root_mean_squared_error: 0.3677 - y2_output_root_mean_squared_error: 0.5468 - val_loss: 0.7742 - val_y1_output_loss: 0.1498 - val_y2_output_loss: 0.6245 - val_y1_output_root_mean_squared_error: 0.3870 - val_y2_output_root_mean_squared_error: 0.7902
# Epoch 498/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4507 - y1_output_loss: 0.1174 - y2_output_loss: 0.3333 - y1_output_root_mean_squared_error: 0.3426 - y2_output_root_mean_squared_error: 0.5774 - val_loss: 0.7429 - val_y1_output_loss: 0.1772 - val_y2_output_loss: 0.5657 - val_y1_output_root_mean_squared_error: 0.4210 - val_y2_output_root_mean_squared_error: 0.7521
# Epoch 499/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4641 - y1_output_loss: 0.1323 - y2_output_loss: 0.3318 - y1_output_root_mean_squared_error: 0.3637 - y2_output_root_mean_squared_error: 0.5760 - val_loss: 1.8370 - val_y1_output_loss: 0.1896 - val_y2_output_loss: 1.6474 - val_y1_output_root_mean_squared_error: 0.4354 - val_y2_output_root_mean_squared_error: 1.2835
# Epoch 500/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4985 - y1_output_loss: 0.1320 - y2_output_loss: 0.3665 - y1_output_root_mean_squared_error: 0.3633 - y2_output_root_mean_squared_error: 0.6054 - val_loss: 1.0601 - val_y1_output_loss: 0.2084 - val_y2_output_loss: 0.8518 - val_y1_output_root_mean_squared_error: 0.4565 - val_y2_output_root_mean_squared_error: 0.9229

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 5/5 [==============================] - 0s 4ms/step - loss: 1.0601 - y1_output_loss: 0.2084 - y2_output_loss: 0.8518 - y1_output_root_mean_squared_error: 0.4565 - y2_output_root_mean_squared_error: 0.9229
# Loss = 1.0601328611373901, Y1_loss = 0.20836322009563446, Y1_mse = 0.4564681947231293, Y2_loss = 0.8517695069313049, Y2_mse = 0.9229136109352112

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
